# %% [markdown]
# Importação das bibliotecas

# %%
import pandas as pd

# %% [markdown]
# Extração dos dados de uma/várias fonte(s)

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/ocorrencia_2010_2020 - ocorrencia_2010_2020.csv', sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)

# %%
df
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                    0
# 1                 40349  ...                    0
# 2                 40351  ...                    0
# 3                 39527  ...                    0
# 4                 40324  ...                    0
# ...                 ...  ...                  ...
# 5747              79804  ...                    0
# 5748              79757  ...                    0
# 5749              79802  ...                    0
# 5750              79756  ...                    0
# 5751              79844  ...                    0
#
# [5752 rows x 9 columns]

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
#ocorrencias unicas serve para procurrar incosistencias
pd.unique(df['ocorrencia_classificacao'])
# Out:
# array(['INCIDENTE', 'ACIDENTE', 'INCIDENTE GRAVE'], dtype=object)

# %%
pd.unique(df['ocorrencia_uf'])
# Out:
# array(['RJ', 'PA', 'MT', 'RS', 'BA', 'AM', 'PR', 'MG', 'SP', 'DF', 'AC',
#        'TO', 'SC', 'GO', 'MA', 'ES', 'PE', 'RR', 'MS', 'CE', 'AP', 'AL',
#        'RO', 'SE', 'PB', 'PI', 'RN', '**'], dtype=object)

# %% [markdown]
# Inconsistencias: '**'

# %%
pd.unique(df['ocorrencia_aerodromo'])
# Out:
# array(['****', 'SBBE', 'SBRJ', 'SBPK', 'SBUY', 'SBCA', 'SBMT', 'SBBR',
#        'SNGU', 'SBGL', 'SBCZ', 'SBPF', 'SBBI', 'SBGR', 'SBPJ', 'SBJC',
#        'SBFL', 'SNCL', 'SBGO', 'SNTY', 'SBSR', 'SBVT', 'SBPC', 'SBSV',
#        'SBCT', 'SBCY', 'SWLC', 'SBJR', 'SBEG', 'SBPR', 'SBLO', 'SBRB',
#        'SBSM', 'SSBL', 'SBMK', 'SBSP', 'SBCF', 'SBUL', 'SWUZ', 'SWNS',
#        'SBFZ', 'SNVR', 'SBPN', 'SSUV', 'SBKP', 'SWNV', 'SBSJ', 'SBML',
#        'SBPA', 'SBME', 'SDPY', 'SWOZ', 'SNEM', 'SBBH', 'SJCY', 'SBSL',
#        'SBMA', 'SWKC', 'SBMO', 'SBJD', 'SDAM', 'SBCJ', 'SNUZ', 'SBPS',
#        'SBJV', 'SNFX', 'SBPL', 'SWXV', 'SBAR', 'SBNF', 'SBRF', 'SSZW',
#        'SWRD', 'SWLV', 'SSGP', 'SDOI', 'SBAE', 'SNDV', 'SSKS', 'SBMG',
#        'SBQV', 'SBIP', 'SBAT', 'SWFR', 'SBBV', 'SBJP', 'SSVN', 'SSPS',
#        'SDPW', 'SBSN', 'SNDT', 'SSKZ', 'SBUR', 'SBTE', '*****', 'SBBU',
#        'SNXT', 'SBRP', 'SSCF', 'SSIE', 'SBCG', 'SBAQ', 'SBIZ', 'SBBP',
# ...

# %% [markdown]
# Inconsistências:
# `'****', '*****', '####', '###!'`
#
# A considerar:
# `'5JTI', '9PAA', '9PFC', '9PFX', '9PHD', '9PSD',`

# %%
#sorted classifica
sorted(pd.unique(df['ocorrencia_aerodromo']))
# Out:
# ['###!',
#  '####',
#  '****',
#  '*****',
#  '5JTI',
#  '9PAA',
#  '9PFC',
#  '9PFX',
#  '9PHD',
#  '9PSD',
#  'SBAE',
#  'SBAN',
#  'SBAQ',
#  'SBAR',
#  'SBAT',
#  'SBAU',
#  'SBBE',
#  'SBBH',
#  'SBBI',
#  'SBBP',
#  'SBBQ',
#  'SBBR',
#  'SBBU',
#  'SBBV',
#  'SBBW',
#  'SBBZ',
#  'SBCA',
#  'SBCB',
#  'SBCF',
#  'SBCG',
#  'SBCJ',
#  'SBCP',
#  'SBCR',
#  'SBCT',
#  'SBCX',
#  'SBCY',
#  'SBCZ',
#  'SBDN',
#  'SBEG',
#  'SBEK',
#  'SBFE',
#  'SBFI',
#  'SBFL',
#  'SBFN',
#  'SBFS',
#  'SBFZ',
#  'SBGL',
#  'SBGO',
#  'SBGP',
#  'SBGR',
#  'SBGV',
#  'SBGW',
#  'SBHT',
#  'SBIH',
#  'SBIL',
#  'SBIP',
#  'SBIT',
#  'SBIZ',
#  'SBJA',
#  'SBJC',
#  'SBJD',
#  'SBJF',
#  'SBJI',
#  'SBJP',
#  'SBJR',
#  'SBJU',
#  'SBJV',
#  'SBKG',
#  'SBKP',
#  'SBLE',
#  'SBLJ',
#  'SBLO',
#  'SBMA',
#  'SBMD',
#  'SBME',
#  'SBMG',
#  'SBMK',
#  'SBML',
#  'SBMO',
#  'SBMQ',
#  'SBMS',
#  'SBMT',
#  'SBMY',
#  'SBNF',
#  'SBNM',
#  'SBNT',
#  'SBPA',
#  'SBPB',
#  'SBPC',
#  'SBPF',
# ...

# %%
dfback = df

# %%
dfback.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0              40211               40211  ...        12:00:00                   0
# 1              40349               40349  ...        11:05:00                   0
# 2              40351               40351  ...        03:00:00                   0
# 3              39527               39527  ...        17:30:00                   0
# 4              40324               40324  ...        19:25:00                   0
#
# [5 rows x 9 columns]

# %%
#NA Não impacta muito em contagem, strings
#Null melhor para operações matematicas, numericos

# %%
df.loc[df.ocorrencia_uf == '**']
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 2227              49474  ...                    0
#
# [1 rows x 9 columns]

# %% [markdown]
# **Limpeza/Tratamento de Dados**

# %%
df.replace(['**','****', '*****', '####', '###!'], pd.NA, inplace=True)

# %%
#df2 = df.replace(['**','****', '*****', '####', '###!'], pd.NA)

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0              40211               40211  ...        12:00:00                   0
# 1              40349               40349  ...        11:05:00                   0
# 2              40351               40351  ...        03:00:00                   0
# 3              39527               39527  ...        17:30:00                   0
# 4              40324               40324  ...        19:25:00                   0
#
# [5 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
#dropa todas as linhas com valores NA
df.dropna()
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 1                 40349  ...                    0
# 2                 40351  ...                    0
# 4                 40324  ...                    0
# 6                 40215  ...                    0
# 8                 39156  ...                    2
# ...                 ...  ...                  ...
# 5743              79824  ...                    0
# 5746              79769  ...                    0
# 5747              79804  ...                    0
# 5749              79802  ...                    0
# 5751              79844  ...                    0
#
# [3403 rows x 9 columns]

# %%
#dropa apenas de um local especifico
df.dropna(subset=['ocorrencia_uf'])
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                    0
# 1                 40349  ...                    0
# 2                 40351  ...                    0
# 3                 39527  ...                    0
# 4                 40324  ...                    0
# ...                 ...  ...                  ...
# 5747              79804  ...                    0
# 5748              79757  ...                    0
# 5749              79802  ...                    0
# 5750              79756  ...                    0
# 5751              79844  ...                    0
#
# [5751 rows x 9 columns]

# %%
df.dropna(subset=['ocorrencia_aerodromo'])
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 1                 40349  ...                    0
# 2                 40351  ...                    0
# 4                 40324  ...                    0
# 6                 40215  ...                    0
# 8                 39156  ...                    2
# ...                 ...  ...                  ...
# 5743              79824  ...                    0
# 5746              79769  ...                    0
# 5747              79804  ...                    0
# 5749              79802  ...                    0
# 5751              79844  ...                    0
#
# [3403 rows x 9 columns]

# %%
#usar dropna apenas quando não impactar muito o DataFrame

# %%
#analisa todo o DataFrame e dropa duplicadas
df.drop_duplicates()
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                    0
# 1                 40349  ...                    0
# 2                 40351  ...                    0
# 3                 39527  ...                    0
# 4                 40324  ...                    0
# ...                 ...  ...                  ...
# 5747              79804  ...                    0
# 5748              79757  ...                    0
# 5749              79802  ...                    0
# 5750              79756  ...                    0
# 5751              79844  ...                    0
#
# [5752 rows x 9 columns]

# %%
#pandera

# %%
pip install pandera
# Out:
# ...
#      |████████████████████████████████| 166 kB 5.4 MB/s
# ...

# %%
df.loc[df.ocorrencia_aerodromo == '5JTI']
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 4337              77684  ...                    2
#
# [1 rows x 9 columns]

# %%
import pandera as pa

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0              40211               40211  ...        12:00:00                   0
# 1              40349               40349  ...        11:05:00                   0
# 2              40351               40351  ...        03:00:00                   0
# 3              39527               39527  ...        17:30:00                   0
# 4              40324               40324  ...        19:25:00                   0
#
# [5 rows x 9 columns]

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %% [markdown]
# ***Validação de Dados***

# %%
#serve para defirnir o tipo de dado de cada coluna para validação
schema = pa.DataFrameSchema(
   columns = {
      'codigo_ocorrencia': pa.Column(pa.Int),
      'codigo_ocorrencia2': pa.Column(pa.Int),
      'ocorrencia_classificacao': pa.Column(pa.String),
      'ocorrencia_cidade': pa.Column(pa.String),
      'ocorrencia_uf': pa.Column(pa.String, pa.Check.str_length(2, 2), nullable=True),
      'ocorrencia_aerodromo': pa.Column(pa.String, pa.Check.str_length(4, 4), nullable=True),
      'ocorrencia_dia': pa.Column(pa.DateTime),
      "ocorrencia_hora":pa.Column(pa.String,pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9]):([0-5][0-9])?$'),nullable=True),
      'total_recomendacoes': pa.Column(pa.Int)
   } 
)

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %% [markdown]
# importancia da validação, no dataset ha um valor NA, é importante paassar o comando nullable=True na validação

# %%
schema.validate(df)
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                    0
# 1                 40349  ...                    0
# 2                 40351  ...                    0
# 3                 39527  ...                    0
# 4                 40324  ...                    0
# ...                 ...  ...                  ...
# 5747              79804  ...                    0
# 5748              79757  ...                    0
# 5749              79802  ...                    0
# 5750              79756  ...                    0
# 5751              79844  ...                    0
#
# [5752 rows x 9 columns]

# %% [markdown]
# **Filtros**
#
# Maneira mais detalhada para ver os dados. Funciona com atribuição de variavel e gaurdando é possivel fazer varfios tipos de ordenamentos. Melhor forma de analisar os dados de maneira detalhada.

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2349
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
filter = df.ocorrencia_uf.isnull()

# %%
df.loc[filter]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 2227              49474  ...                    0
#
# [1 rows x 9 columns]

# %%
filter2 = df.ocorrencia_aerodromo.isnull()

# %%
df.loc[filter2]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                    0
# 3                 39527  ...                    0
# 5                 39807  ...                    0
# 7                 39707  ...                    3
# 9                 39711  ...                    0
# ...                 ...  ...                  ...
# 5741              79754  ...                    0
# 5744              79753  ...                    0
# 5745              79755  ...                    0
# 5748              79757  ...                    0
# 5750              79756  ...                    0
#
# [2349 rows x 9 columns]

# %%
#numeor validos por coluna
df.count()
# Out:
# codigo_ocorrencia           5752
# codigo_ocorrencia2          5752
# ocorrencia_classificacao    5752
# ocorrencia_cidade           5752
# ocorrencia_uf               5751
# ocorrencia_aerodromo        3403
# ocorrencia_dia              5752
# ocorrencia_hora             5751
# total_recomendacoes         5752
# dtype: int64

# %%
#analisar nulos
#analisar validos
#observar se a conta fecha

# %%
filter1 = df.ocorrencia_cidade == 'RIO DE JANEIRO'

# %%
df.loc[filter1]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                    0
# 2                 40351  ...                    0
# 19                44575  ...                    0
# 23                40311  ...                    0
# 24                41577  ...                    0
# ...                 ...  ...                  ...
# 5703              79702  ...                    0
# 5706              79707  ...                    0
# 5710              79714  ...                    0
# 5749              79802  ...                    0
# 5751              79844  ...                    0
#
# [321 rows x 9 columns]

# %%
df.loc[filter1, ['ocorrencia_cidade', 'ocorrencia_dia', 'total_recomendacoes']]
# Out:
#      ocorrencia_cidade ocorrencia_dia  total_recomendacoes
# 0       RIO DE JANEIRO     2010-01-03                    0
# 2       RIO DE JANEIRO     2010-01-03                    0
# 19      RIO DE JANEIRO     2010-01-17                    0
# 23      RIO DE JANEIRO     2010-01-19                    0
# 24      RIO DE JANEIRO     2010-01-19                    0
# ...                ...            ...                  ...
# 5703    RIO DE JANEIRO     2020-12-02                    0
# 5706    RIO DE JANEIRO     2020-12-05                    0
# 5710    RIO DE JANEIRO     2020-12-08                    0
# 5749    RIO DE JANEIRO     2020-12-30                    0
# 5751    RIO DE JANEIRO     2020-12-31                    0
#
# [321 rows x 3 columns]

# %%
filter2 = df.ocorrencia_classificacao == 'ACIDENTE'
filter3 = df.ocorrencia_uf == 'RJ'

# %%
df.loc[filter2 & filter3]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 31                39323  ...                    0
# 49                39295  ...                    0
# 149               40447  ...                    0
# 155               40554  ...                    8
# 248               41729  ...                    0
# ...                 ...  ...                  ...
# 4966              78744  ...                    0
# 5411              79309  ...                    0
# 5503              79430  ...                    0
# 5636              79621  ...                    0
# 5716              79724  ...                    0
#
# [74 rows x 9 columns]

# %%
df.loc[filter2 | filter3]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                    0
# 2                 40351  ...                    0
# 3                 39527  ...                    0
# 11                40069  ...                    8
# 13                39507  ...                    2
# ...                 ...  ...                  ...
# 5740              79751  ...                    0
# 5743              79824  ...                    0
# 5745              79755  ...                    0
# 5749              79802  ...                    0
# 5751              79844  ...                    0
#
# [2286 rows x 9 columns]

# %%
filter4 = df.ocorrencia_classificacao.isin(['ACIDENTE', 'INCIDENTE'])
filter5 = df.ocorrencia_uf == 'SP'

# %%
df.loc[filter4 & filter5]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 11                40069  ...                    8
# 16                39809  ...                    0
# 18                39828  ...                    0
# 26                39847  ...                    0
# 27                39768  ...                    0
# ...                 ...  ...                  ...
# 5683              79730  ...                    0
# 5696              79692  ...                    0
# 5700              79699  ...                    0
# 5742              79800  ...                    0
# 5747              79804  ...                    0
#
# [1236 rows x 9 columns]

# %%
filtro_letra = df.ocorrencia_cidade.str[-1] == 'A'
df.loc[filtro_letra]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 7                 39707  ...                    3
# 12                40414  ...                    0
# 15                39315  ...                    0
# 25                39772  ...                    0
# 26                39847  ...                    0
# ...                 ...  ...                  ...
# 5738              79787  ...                    0
# 5739              79749  ...                    0
# 5743              79824  ...                    0
# 5744              79753  ...                    0
# 5750              79756  ...                    0
#
# [1556 rows x 9 columns]

# %%
filtro_letra = df.ocorrencia_cidade.str.contains('RIO')
df.loc[filtro_letra]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                    0
# 2                 40351  ...                    0
# 3                 39527  ...                    0
# 19                44575  ...                    0
# 23                40311  ...                    0
# ...                 ...  ...                  ...
# 5717              79719  ...                    0
# 5724              79740  ...                    0
# 5743              79824  ...                    0
# 5749              79802  ...                    0
# 5751              79844  ...                    0
#
# [489 rows x 9 columns]

# %%
filtro_letra = df.ocorrencia_cidade.str[-2:] == 'RA'
df.loc[filtro_letra]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 48                39235  ...                    3
# 53                39405  ...                    1
# 61                41377  ...                    0
# 68                40318  ...                    0
# 187               41574  ...                    0
# ...                 ...  ...                  ...
# 5488              79412  ...                    0
# 5628              79595  ...                    0
# 5685              79687  ...                    0
# 5722              79738  ...                    0
# 5734              79766  ...                    0
#
# [116 rows x 9 columns]

# %%
filtro_contem = df.ocorrencia_cidade.str.contains('FOR')
df.loc[filtro_contem]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 68                40318  ...                    0
# 114               40288  ...                    0
# 187               41574  ...                    0
# 207               41272  ...                    0
# 213               41482  ...                    0
# ...                 ...  ...                  ...
# 5467              79503  ...                    0
# 5605              79555  ...                    0
# 5617              79589  ...                    0
# 5734              79766  ...                    0
# 5738              79787  ...                    0
#
# [81 rows x 9 columns]

# %%
filtro_contem = df.ocorrencia_cidade.str.contains('FOR|MA')
df.loc[filtro_contem]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 7                 39707  ...                    3
# 13                39507  ...                    2
# 15                39315  ...                    0
# 35                39487  ...                    0
# 68                40318  ...                    0
# ...                 ...  ...                  ...
# 5738              79787  ...                    0
# 5739              79749  ...                    0
# 5741              79754  ...                    0
# 5745              79755  ...                    0
# 5746              79769  ...                    0
#
# [569 rows x 9 columns]

# %%
filtro_data = df.ocorrencia_dia.dt.year == 2018

# %%
df.loc[filtro_data]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 4302              77607  ...                    0
# 4303              77608  ...                    0
# 4304              77610  ...                    0
# 4305              77616  ...                    0
# 4306              77617  ...                    0
# ...                 ...  ...                  ...
# 4741              78410  ...                    0
# 4742              78390  ...                    1
# 4743              78433  ...                    0
# 4744              78406  ...                    0
# 4745              78394  ...                    0
#
# [444 rows x 9 columns]

# %%
df.loc[filtro_data & filter5 & filter2]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 4320              77636  ...                    0
# 4345              77687  ...                    0
# 4351              77685  ...                    1
# 4366              77717  ...                    1
# 4387              77743  ...                    0
# 4392              77753  ...                    0
# 4403              77770  ...                    1
# 4411              77773  ...                    0
# 4459              79567  ...                    0
# 4463              77866  ...                    0
# 4474              77893  ...                    1
# 4489              77910  ...                    0
# 4495              77919  ...                    0
# 4502              77942  ...                    0
# 4538              78018  ...                    2
# 4546              78031  ...                    6
# 4577              78079  ...                    0
# 4604              78147  ...                    1
# ...

# %%
df_extra = df.loc[filtro_data & filter5 & filter2]

# %%
df_extra
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 4320              77636  ...                    0
# 4345              77687  ...                    0
# 4351              77685  ...                    1
# 4366              77717  ...                    1
# 4387              77743  ...                    0
# 4392              77753  ...                    0
# 4403              77770  ...                    1
# 4411              77773  ...                    0
# 4459              79567  ...                    0
# 4463              77866  ...                    0
# 4474              77893  ...                    1
# 4489              77910  ...                    0
# 4495              77919  ...                    0
# 4502              77942  ...                    0
# 4538              78018  ...                    2
# 4546              78031  ...                    6
# 4577              78079  ...                    0
# 4604              78147  ...                    1
# ...

# %% [markdown]
# ## **BACKUP MANEIRA ATUAL NO COLAB**
# `databack = df.copy()`

# %%
filter_ano = df.ocorrencia_dia.dt.year == 2016
filter_mes = df.ocorrencia_dia.dt.month == 11
filter_dia_inicial = df.ocorrencia_dia.dt.day > 2
filter_dia_final = df.ocorrencia_dia.dt.day < 22
df.loc[filter_ano & filter_mes & filter_dia_inicial & filter_dia_final & filter5]
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 3806              65936  ...                    0
# 3807              65994  ...                    0
# 3808              65953  ...                    0
# 3812              65974  ...                    0
# 3813              65990  ...                    0
# 3821              66082  ...                    0
# 3822              66019  ...                    0
# 3826              66020  ...                    0
#
# [8 rows x 9 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df['data_hora'] = pd.to_datetime(df.ocorrencia_dia.astype(str) + ' '+df.ocorrencia_hora)

# %%
df
# Out:
#       codigo_ocorrencia  ...           data_hora
# 0                 40211  ... 2010-01-03 12:00:00
# 1                 40349  ... 2010-01-03 11:05:00
# 2                 40351  ... 2010-01-03 03:00:00
# 3                 39527  ... 2010-01-04 17:30:00
# 4                 40324  ... 2010-01-05 19:25:00
# ...                 ...  ...                 ...
# 5747              79804  ... 2020-12-29 19:00:00
# 5748              79757  ... 2020-12-30 18:30:00
# 5749              79802  ... 2020-12-30 00:54:00
# 5750              79756  ... 2020-12-31 09:00:00
# 5751              79844  ... 2020-12-31 13:24:00
#
# [5752 rows x 10 columns]

# %%
periodo_inicial = df.data_hora >= '2018-10-01 00:00:00'
periodo_final = df.data_hora <= '2018-10-15 23:00:00'

# %%
df.loc[periodo_inicial & periodo_final]
# Out:
#       codigo_ocorrencia  ...           data_hora
# 4643              78214  ... 2018-10-01 14:04:00
# 4644              78228  ... 2018-10-01 14:20:00
# 4645              78298  ... 2018-10-04 10:40:00
# 4646              78233  ... 2018-10-05 09:24:00
# 4647              78235  ... 2018-10-08 20:50:00
# 4648              78237  ... 2018-10-09 09:30:00
# 4649              78247  ... 2018-10-09 02:00:00
# 4650              78238  ... 2018-10-11 13:06:00
# 4651              78240  ... 2018-10-11 21:00:00
# 4652              78241  ... 2018-10-12 14:15:00
# 4653              78239  ... 2018-10-13 10:10:00
# 4654              78243  ... 2018-10-13 19:45:00
# 4655              78246  ... 2018-10-13 19:00:00
#
# [13 rows x 10 columns]

# %%
#df.data_hora.dt.time.between_time()

# %% [markdown]
# # **Filtros para Load / Carregamento**

# %%
filtro_ano = df.ocorrencia_dia.dt.year == 2012
filtro_mes = df.ocorrencia_dia.dt.month == 3
df2012marco = df.loc[filtro_ano & filtro_mes]

# %%
df2012marco
# Out:
#       codigo_ocorrencia  ...           data_hora
# 1223              45727  ... 2012-03-01 12:50:00
# 1224              45526  ... 2012-03-02 12:50:00
# 1225              45589  ... 2012-03-02 17:35:00
# 1226              45707  ... 2012-03-02 22:12:00
# 1227              45610  ... 2012-03-03 13:00:00
# ...                 ...  ...                 ...
# 1279              45773  ... 2012-03-29 20:33:00
# 1280              45785  ... 2012-03-29 15:20:00
# 1281              45754  ... 2012-03-30 14:30:00
# 1282              45774  ... 2012-03-30 13:31:00
# 1283              45731  ... 2012-03-31 19:21:00
#
# [61 rows x 10 columns]

# %%
#numero de dados validos
df2012marco.count()
# Out:
# codigo_ocorrencia           61
# codigo_ocorrencia2          61
# ocorrencia_classificacao    61
# ocorrencia_cidade           61
# ocorrencia_uf               61
# ocorrencia_aerodromo        30
# ocorrencia_dia              61
# ocorrencia_hora             61
# total_recomendacoes         61
# data_hora                   61
# dtype: int64

# %%
df2012marco.groupby(['ocorrencia_classificacao']).ocorrencia_classificacao.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           14
# INCIDENTE          43
# INCIDENTE GRAVE     4
# Name: ocorrencia_classificacao, dtype: int64

# %%
#De acordo com os valores mostrara uma lista e vai contar quantos de cada tem

# %%
df.groupby(['ocorrencia_classificacao']).ocorrencia_classificacao.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           1844
# INCIDENTE          3171
# INCIDENTE GRAVE     737
# Name: ocorrencia_classificacao, dtype: int64

# %%
df2012marco.groupby(['ocorrencia_classificacao']).ocorrencia_aerodromo.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE            6
# INCIDENTE          22
# INCIDENTE GRAVE     2
# Name: ocorrencia_aerodromo, dtype: int64

# %%
df2012marco.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           14
# INCIDENTE          43
# INCIDENTE GRAVE     4
# dtype: int64

# %%
df2012marco.groupby(['ocorrencia_classificacao']).size().sort_values()
# Out:
# ocorrencia_classificacao
# INCIDENTE GRAVE     4
# ACIDENTE           14
# INCIDENTE          43
# dtype: int64

# %%
df2012marco.groupby(['ocorrencia_classificacao']).size().sort_values(ascending=False)
# Out:
# ocorrencia_classificacao
# INCIDENTE          43
# ACIDENTE           14
# INCIDENTE GRAVE     4
# dtype: int64

# %%
ano2011 = df.ocorrencia_dia.dt.year == 2011
estados = df.ocorrencia_uf.isin(['SP','RJ','MG','ES'])

dfsudeste2011 = df.loc[ano2011 & estados]

# %%
dfsudeste2011
# Out:
#       codigo_ocorrencia  ...           data_hora
# 552               43633  ... 2011-01-01 19:35:00
# 554               43643  ... 2011-01-02 17:18:00
# 558               43631  ... 2011-01-05 15:36:00
# 559               43642  ... 2011-01-05 22:06:00
# 560               43630  ... 2011-01-06 11:30:00
# ...                 ...  ...                 ...
# 1120              45327  ... 2011-12-29 06:48:00
# 1122              51880  ... 2011-12-29 09:00:00
# 1123              51881  ... 2011-12-29 17:18:00
# 1124              51882  ... 2011-12-29 14:11:00
# 1126              45291  ... 2011-12-30 17:40:00
#
# [262 rows x 10 columns]

# %%
dfsudeste2011.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE            65
# INCIDENTE          176
# INCIDENTE GRAVE     21
# dtype: int64

# %%
dfsudeste2011.count()
# Out:
# codigo_ocorrencia           262
# codigo_ocorrencia2          262
# ocorrencia_classificacao    262
# ocorrencia_cidade           262
# ocorrencia_uf               262
# ocorrencia_aerodromo        117
# ocorrencia_dia              262
# ocorrencia_hora             262
# total_recomendacoes         262
# data_hora                   262
# dtype: int64

# %%
dfsudeste2011.groupby(['ocorrencia_classificacao', 'ocorrencia_uf']).size()
# Out:
# ocorrencia_classificacao  ocorrencia_uf
# ACIDENTE                  ES                1
#                           MG               12
#                           RJ                9
#                           SP               43
# INCIDENTE                 ES                6
#                           MG               23
#                           RJ               63
#                           SP               84
# INCIDENTE GRAVE           ES                2
#                           MG                7
#                           RJ                5
#                           SP                7
# dtype: int64

# %%
dfsudeste2011.groupby(['ocorrencia_cidade']).size().sort_values(ascending=False)
# Out:
# ocorrencia_cidade
# RIO DE JANEIRO    44
# GUARULHOS         20
# SÃO PAULO         20
# BELO HORIZONTE    14
# RIBEIRÃO PRETO    14
#                   ..
# MARÍLIA            1
# VILA VELHA         1
# MANHUAÇU           1
# JAÍBA              1
# AIMORÉS            1
# Length: 84, dtype: int64

# %%
dfsudeste2011.groupby(['ocorrencia_aerodromo'], dropna=False).total_recomendacoes.sum()
# Out:
# ocorrencia_aerodromo
# SBAU     3
# SBBH     0
# SBBP     0
# SBBU     2
# SBCB     0
# SBCF     0
# SBCP     0
# SBGL     0
# SBGR     0
# SBIP     0
# SBJD     0
# SBJR     2
# SBKP     0
# SBME     0
# SBML     0
# SBMT     0
# SBPR     1
# SBRJ     0
# SBRP    10
# SBSJ     0
# SBSP     5
# SBSR     0
# SBUL    20
# SBUR     0
# SBVT     0
# SDAA     0
# SDBB     0
# SDBV     0
# SDCO     0
# SDET     0
# SDIO    11
# SDJA     0
# SDMC     0
# SDOR     0
# SDPW     0
# SDTB     2
# SDTK     0
# SDVE     0
# SIBX     0
# SIRS     0
# SNPD     0
# NaN     68
# Name: total_recomendacoes, dtype: int64

# %% [markdown]
# CARREGAMENTO PARA CSV

# %%
dfsudeste2011.to_csv('sudeste2011.csv')

# %%
#dfsudeste2011.to_csv('sudeste2011.csv', index=False)

# %%
df2012marco.to_csv('marco2012.csv')

# %%
teste01 = pd.read_csv('/content/sudeste2011.csv')

# %%
teste01
# Out:
#      Unnamed: 0  codigo_ocorrencia  ...  total_recomendacoes            data_hora
# 0           552              43633  ...                   10  2011-01-01 19:35:00
# 1           554              43643  ...                    0  2011-01-02 17:18:00
# 2           558              43631  ...                    0  2011-01-05 15:36:00
# 3           559              43642  ...                    0  2011-01-05 22:06:00
# 4           560              43630  ...                    0  2011-01-06 11:30:00
# ..          ...                ...  ...                  ...                  ...
# 257        1120              45327  ...                    0  2011-12-29 06:48:00
# 258        1122              51880  ...                    0  2011-12-29 09:00:00
# 259        1123              51881  ...                    0  2011-12-29 17:18:00
# 260        1124              51882  ...                    0  2011-12-29 14:11:00
# ...

# %%
teste02 = pd.read_csv('/content/marco2012.csv')

# %%
teste02
# Out:
#     Unnamed: 0  codigo_ocorrencia  ...  total_recomendacoes            data_hora
# 0         1223              45727  ...                    0  2012-03-01 12:50:00
# 1         1224              45526  ...                    0  2012-03-02 12:50:00
# 2         1225              45589  ...                    0  2012-03-02 17:35:00
# 3         1226              45707  ...                    0  2012-03-02 22:12:00
# 4         1227              45610  ...                    0  2012-03-03 13:00:00
# ..         ...                ...  ...                  ...                  ...
# 56        1279              45773  ...                    0  2012-03-29 20:33:00
# 57        1280              45785  ...                    3  2012-03-29 15:20:00
# 58        1281              45754  ...                    0  2012-03-30 14:30:00
# 59        1282              45774  ...                    0  2012-03-30 13:31:00
# 60        1283              45731  ...                    0  2012-03-31 19:21:00
#
# ...
