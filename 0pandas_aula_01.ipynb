# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/ocorrencia_2010_2020 - ocorrencia_2010_2020.csv', sep=';', parse_dates=['ocorrencia_dia'], dayfirst=True)

# %%
df
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 0                 40211  ...                    0
# 1                 40349  ...                    0
# 2                 40351  ...                    0
# 3                 39527  ...                    0
# 4                 40324  ...                    0
# ...                 ...  ...                  ...
# 5747              79804  ...                    0
# 5748              79757  ...                    0
# 5749              79802  ...                    0
# 5750              79756  ...                    0
# 5751              79844  ...                    0
#
# [5752 rows x 9 columns]

# %%
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0              40211               40211  ...        12:00:00                   0
# 1              40349               40349  ...        11:05:00                   0
# 2              40351               40351  ...        03:00:00                   0
# 3              39527               39527  ...        17:30:00                   0
# 4              40324               40324  ...        19:25:00                   0
#
# [5 rows x 9 columns]

# %%
df.tail()
# Out:
#       codigo_ocorrencia  ...  total_recomendacoes
# 5747              79804  ...                    0
# 5748              79757  ...                    0
# 5749              79802  ...                    0
# 5750              79756  ...                    0
# 5751              79844  ...                    0
#
# [5 rows x 9 columns]

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df.ocorrencia_dia.dt.day
# Out:
# 0        3
# 1        3
# 2        3
# 3        4
# 4        5
#         ..
# 5747    29
# 5748    30
# 5749    30
# 5750    31
# 5751    31
# Name: ocorrencia_dia, Length: 5752, dtype: int64

# %%
df.loc[5751, 'codigo_ocorrencia2']
# Out:
# 79844

# %%
df.loc[0,'ocorrencia_aerodromo']
# Out:
# '****'

# %%
df.loc[[5, 15, 35]]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 5               39807               39807  ...        17:53:00                   0
# 15              39315               39315  ...        21:22:00                   0
# 35              39487               39487  ...        16:50:00                   0
#
# [3 rows x 9 columns]

# %%
df.loc[[5, 15, 35], 'ocorrencia_aerodromo']
# Out:
# 5     ****
# 15    ****
# 35    SBPJ
# Name: ocorrencia_aerodromo, dtype: object

# %%
df.loc[:, 'ocorrencia_cidade']
# Out:
# 0           RIO DE JANEIRO
# 1                    BELÉM
# 2           RIO DE JANEIRO
# 3       LUCAS DO RIO VERDE
# 4                  PELOTAS
#                ...
# 5747              CAMPINAS
# 5748     LAGOA DA CONFUSÃO
# 5749        RIO DE JANEIRO
# 5750             VICENTINA
# 5751        RIO DE JANEIRO
# Name: ocorrencia_cidade, Length: 5752, dtype: object

# %%
df.loc[0:20]
# Out:
#     codigo_ocorrencia  codigo_ocorrencia2  ... ocorrencia_hora total_recomendacoes
# 0               40211               40211  ...        12:00:00                   0
# 1               40349               40349  ...        11:05:00                   0
# 2               40351               40351  ...        03:00:00                   0
# 3               39527               39527  ...        17:30:00                   0
# 4               40324               40324  ...        19:25:00                   0
# 5               39807               39807  ...        17:53:00                   0
# 6               40215               40215  ...        18:40:00                   0
# 7               39707               39707  ...        12:30:00                   3
# 8               39156               39156  ...        23:15:00                   2
# 9               39711               39711  ...        20:00:00                   0
# ...

# %%
df.loc[10:0:-1,'ocorrencia_classificacao':'ocorrencia_cidade']
# Out:
#    ocorrencia_classificacao   ocorrencia_cidade
# 10                INCIDENTE    SÃO PEDRO DO SUL
# 9           INCIDENTE GRAVE       PARÁ DE MINAS
# 8           INCIDENTE GRAVE            CASCAVEL
# 7           INCIDENTE GRAVE            CANUTAMA
# 6                 INCIDENTE               COARI
# 5                 INCIDENTE            SALVADOR
# 4                 INCIDENTE             PELOTAS
# 3                  ACIDENTE  LUCAS DO RIO VERDE
# 2                 INCIDENTE      RIO DE JANEIRO
# 1                 INCIDENTE               BELÉM
# 0                 INCIDENTE      RIO DE JANEIRO

# %%
df.ocorrencia_classificacao.is_unique
# Out:
# False

# %%
df.set_index('codigo_ocorrencia')
# Out:
#                    codigo_ocorrencia2  ... total_recomendacoes
# codigo_ocorrencia                      ...
# 40211                           40211  ...                   0
# 40349                           40349  ...                   0
# 40351                           40351  ...                   0
# 39527                           39527  ...                   0
# 40324                           40324  ...                   0
# ...                               ...  ...                 ...
# 79804                           79804  ...                   0
# 79757                           79757  ...                   0
# 79802                           79802  ...                   0
# 79756                           79756  ...                   0
# 79844                           79844  ...                   0
#
# [5752 rows x 8 columns]

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
df.head()
# Out:
#                    codigo_ocorrencia2  ... total_recomendacoes
# codigo_ocorrencia                      ...
# 40211                           40211  ...                   0
# 40349                           40349  ...                   0
# 40351                           40351  ...                   0
# 39527                           39527  ...                   0
# 40324                           40324  ...                   0
#
# [5 rows x 8 columns]

# %%
df.dtypes
# Out:
# codigo_ocorrencia2                   int64
# ocorrencia_classificacao            object
# ocorrencia_cidade                   object
# ocorrencia_uf                       object
# ocorrencia_aerodromo                object
# ocorrencia_dia              datetime64[ns]
# ocorrencia_hora                     object
# total_recomendacoes                  int64
# dtype: object

# %%
df
# Out:
#                    codigo_ocorrencia2  ... total_recomendacoes
# codigo_ocorrencia                      ...
# 40211                           40211  ...                   0
# 40349                           40349  ...                   0
# 40351                           40351  ...                   0
# 39527                           39527  ...                   0
# 40324                           40324  ...                   0
# ...                               ...  ...                 ...
# 79804                           79804  ...                   0
# 79757                           79757  ...                   0
# 79802                           79802  ...                   0
# 79756                           79756  ...                   0
# 79844                           79844  ...                   0
#
# [5752 rows x 8 columns]

# %%
df.loc[40211]
# Out:
# codigo_ocorrencia2                        40211
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                RIO DE JANEIRO
# ocorrencia_uf                                RJ
# ocorrencia_aerodromo                       ****
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        12:00:00
# total_recomendacoes                           0
# Name: 40211, dtype: object

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#       codigo_ocorrencia2  ... total_recomendacoes
# 0                  40211  ...                   0
# 1                  40349  ...                   0
# 2                  40351  ...                   0
# 3                  39527  ...                   0
# 4                  40324  ...                   0
# ...                  ...  ...                 ...
# 5747               79804  ...                   0
# 5748               79757  ...                   0
# 5749               79802  ...                   0
# 5750               79756  ...                   0
# 5751               79844  ...                   0
#
# [5752 rows x 8 columns]

# %%
df.head()
# Out:
#    codigo_ocorrencia2  ... total_recomendacoes
# 0               40211  ...                   0
# 1               40349  ...                   0
# 2               40351  ...                   0
# 3               39527  ...                   0
# 4               40324  ...                   0
#
# [5 rows x 8 columns]

# %%
df['backup'] = df.ocorrencia_aerodromo

# %%
df.head()
# Out:
#    codigo_ocorrencia2 ocorrencia_classificacao  ... total_recomendacoes backup
# 0               40211                INCIDENTE  ...                   0   ****
# 1               40349                INCIDENTE  ...                   0   SBBE
# 2               40351                INCIDENTE  ...                   0   SBRJ
# 3               39527                 ACIDENTE  ...                   0   ****
# 4               40324                INCIDENTE  ...                   0   SBPK
#
# [5 rows x 9 columns]

# %%
df.drop(['backup'],axis=1, inplace=True)
#axis = 0 = x, axis = 1 = y

# %%
df.head()
# Out:
#    codigo_ocorrencia2  ... total_recomendacoes
# 0               40211  ...                   0
# 1               40349  ...                   0
# 2               40351  ...                   0
# 3               39527  ...                   0
# 4               40324  ...                   0
#
# [5 rows x 8 columns]

# %%
df['backup_aerodromo'] = df.ocorrencia_aerodromo

# %%
df.head()
# Out:
#    codigo_ocorrencia2  ... backup_aerodromo
# 0               40211  ...             ****
# 1               40349  ...             SBBE
# 2               40351  ...             SBRJ
# 3               39527  ...             ****
# 4               40324  ...             SBPK
#
# [5 rows x 9 columns]

# %%
df.loc[0, 'ocorrencia_aerodromo'] = 'PHYLYP'
#atribuir a celula especifica, eixo x e y, se nao a linha inteira sera alterada

# %%
df.head()
# Out:
#    codigo_ocorrencia2  ... total_recomendacoes
# 0               40211  ...                   0
# 1               40349  ...                   0
# 2               40351  ...                   0
# 3               39527  ...                   0
# 4               40324  ...                   0
#
# [5 rows x 8 columns]

# %%
#df.loc[:, 'backup_aerodromo'] = 'Fuil Alterado'
#altera todos os dados da coluna
# Alterar um campo específico da tabela informando linha e coluna
# df.loc
#       [limha,coluna] = Altera um dado
#       [linha] = Altera toda a linha
#       [:, coluna] = Altera toda a coluna

# %%
df.loc[df.ocorrencia_uf == 'MT',['ocorrencia_classificacao']] = 'PHY'
#com loc troca quando eu tenho um valor espcificio a substituir 
#nova classificação

# %%
df
# Out:
#       codigo_ocorrencia2  ... backup_aerodromo
# 0                  40211  ...             ****
# 1                  40349  ...             SBBE
# 2                  40351  ...             SBRJ
# 3                  39527  ...             ****
# 4                  40324  ...             SBPK
# ...                  ...  ...              ...
# 5747               79804  ...             SBKP
# 5748               79757  ...             ****
# 5749               79802  ...             SBGL
# 5750               79756  ...             ****
# 5751               79844  ...             SBJR
#
# [5752 rows x 9 columns]

# %%
df.loc[df.ocorrencia_uf == 'MT']
# Out:
#       codigo_ocorrencia2  ... backup_aerodromo
# 3                  39527  ...             ****
# 13                 39507  ...             ****
# 28                 39321  ...             ****
# 53                 39405  ...             ****
# 69                 39727  ...             SBCY
# ...                  ...  ...              ...
# 5679               79678  ...             ****
# 5687               79689  ...            *****
# 5699               79697  ...             ****
# 5711               79717  ...             ****
# 5741               79754  ...             ****
#
# [292 rows x 9 columns]

# %%
df.head()
# Out:
#    codigo_ocorrencia2  ... backup_aerodromo
# 0               40211  ...             ****
# 1               40349  ...             SBBE
# 2               40351  ...             SBRJ
# 3               39527  ...             ****
# 4               40324  ...             SBPK
#
# [5 rows x 9 columns]

# %%
df.replace(['****', '*****', '####',], pd.NA, inplace=True)
#replace ausencia de dados not avaliable, mlhor deixar nao avaliale 
#do que incosistente, replace troca em todos os locais do df
#

# %%
df.tail()
# Out:
#       codigo_ocorrencia2  ... backup_aerodromo
# 5747               79804  ...             SBKP
# 5748               79757  ...             <NA>
# 5749               79802  ...             SBGL
# 5750               79756  ...             <NA>
# 5751               79844  ...             SBJR
#
# [5 rows x 9 columns]

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  0
# ocorrencia_aerodromo        2343
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# backup_aerodromo            2344
# dtype: int64

# %%
df.rename(columns={'ocorrencia_classificacao': 'a', 'ocorrencia_cidade': 'b'}, inplace=True)

# %%
df.head()
# Out:
#    codigo_ocorrencia2          a  ... ocorrencia_hora total_recomendacoes
# 0               40211  INCIDENTE  ...        12:00:00                   0
# 1               40349  INCIDENTE  ...        11:05:00                   0
# 2               40351  INCIDENTE  ...        03:00:00                   0
# 3               39527   ACIDENTE  ...        17:30:00                   0
# 4               40324  INCIDENTE  ...        19:25:00                   0
#
# [5 rows x 8 columns]
