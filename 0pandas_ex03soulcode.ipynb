# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/datasets/Acessos_Banda_Larga_Fixa_2021.csv', sep=';')

# %%
df.tail(10)
# Out:
#           Ano  Mês Grupo Econômico  ... Meio de Acesso   Tipo de Pessoa Acessos
# 3210054  2021    1          OUTROS  ...             AR    Pessoa Física      29
# 3210055  2021    1          OUTROS  ...             AR  Pessoa Jurídica       2
# 3210056  2021    1          OUTROS  ...             AR  Pessoa Jurídica       5
# 3210057  2021    1          OUTROS  ...          Fibra    Pessoa Física       1
# 3210058  2021    1          OUTROS  ...             AR  Pessoa Jurídica       2
# 3210059  2021    1          OUTROS  ...             AR  Pessoa Jurídica      10
# 3210060  2021    1          OUTROS  ...             AR    Pessoa Física      19
# 3210061  2021    1          OUTROS  ...             AR    Pessoa Física      23
# 3210062  2021    1          OUTROS  ...          Fibra    Pessoa Física       1
# 3210063  2021    1          OUTROS  ...             AR    Pessoa Física      17
#
# [10 rows x 14 columns]

# %%
pd.unique(df['Tecnologia'])
# Out:
# array(['ETHERNET', 'DWDM', 'FIBRA', 'HDSL', 'WIMAX', 'HFC', 'Wi-Fi', 'NR',
#        'FR', 'VDSL', 'FWA', 'ADSL1', 'ADSL2', 'Cable Modem', 'PLC', 'ATM',
#        'TDMA', 'DTH', 'EDGE', 'MMDS', 'OFDMA/TDD', 'VSAT', 'LTE', 'GSM',
#        'GPRS', 'SDH', 'PDH', 'WCDMA', 'Indeterminado', 'HSPA'],
#       dtype=object)

# %%
df.loc[df.Tecnologia == 'FTTH',['Tecnologia']] = 'FIBRA'

# %%
df.loc[df.Tecnologia == 'FTTB', ['Tecnologia']] = 'FIBRA'

# %%
df.dtypes
# Out:
# Ano                       int64
# Mês                       int64
# Grupo Econômico          object
# Empresa                  object
# CNPJ                      int64
# Porte da Prestadora      object
# UF                       object
# Município                object
# Código IBGE Município     int64
# Faixa de Velocidade      object
# Tecnologia               object
# Meio de Acesso           object
# Tipo de Pessoa           object
# Acessos                   int64
# dtype: object

# %%
pd.unique(df['Meio de Acesso'])
# Out:
# array(['Fibra', 'AR', 'Rádio', 'Satélite', 'Cabo Metálico',
#        'Cabo Coaxial', 'Indeterminado'], dtype=object)

# %%
df.loc[df.Tecnologia == 'WIMAX', ['Meio de Acesso']] = 'AR'

# %%
df.loc[df.Tecnologia == 'Wi-Fi', ['Meio de Acesso']] = 'AR'

# %%
df
# Out:
#           Ano  Mês  ...   Tipo de Pessoa Acessos
# 0        2021    7  ...  Pessoa Jurídica      10
# 1        2021    7  ...  Pessoa Jurídica       1
# 2        2021    7  ...  Pessoa Jurídica       2
# 3        2021    7  ...  Pessoa Jurídica       2
# 4        2021    7  ...  Pessoa Jurídica       3
# ...       ...  ...  ...              ...     ...
# 3210059  2021    1  ...  Pessoa Jurídica      10
# 3210060  2021    1  ...    Pessoa Física      19
# 3210061  2021    1  ...    Pessoa Física      23
# 3210062  2021    1  ...    Pessoa Física       1
# 3210063  2021    1  ...    Pessoa Física      17
#
# [3210064 rows x 14 columns]

# %%
df.replace(['LTE', 'GSM', 'GPRS' 'OFMDA/TDD', 'EDGE'], '4G', inplace=True)

# %%
pd.unique(df['Tecnologia'])
# Out:
# array(['ETHERNET', 'DWDM', 'FIBRA', 'HDSL', 'WIMAX', 'HFC', 'Wi-Fi', 'NR',
#        'FR', 'VDSL', 'FWA', 'ADSL1', 'ADSL2', 'Cable Modem', 'PLC', 'ATM',
#        'TDMA', 'DTH', '4G', 'MMDS', 'OFDMA/TDD', 'VSAT', 'GPRS', 'SDH',
#        'PDH', 'WCDMA', 'Indeterminado', 'HSPA'], dtype=object)

# %%
pd.unique(df['Grupo Econômico'])
# Out:
# array(['ALGAR (CTBC TELECOM)', 'OUTROS', 'OI', 'TELECOM AMERICAS',
#        'PREFEITURA DE LONDRINA/COPEL', 'TELECOM ITALIA', 'TELEFÔNICA',
#        'BT', 'CABO', 'DATORA', 'SKY/AT&T', 'NOSSATV'], dtype=object)

# %%
df.rename(columns={'Grupo Econômico': 'Grupo_Economico'}, inplace=True)

# %%
filter01 = df.Grupo_Economico == 'OUTROS'
df.loc[filter01]
# Out:
#           Ano  Mês Grupo_Economico  ... Meio de Acesso   Tipo de Pessoa Acessos
# 3        2021    7          OUTROS  ...          Fibra  Pessoa Jurídica       2
# 6        2021    7          OUTROS  ...          Fibra  Pessoa Jurídica       2
# 12       2021    7          OUTROS  ...          Fibra  Pessoa Jurídica       2
# 13       2021    7          OUTROS  ...          Fibra  Pessoa Jurídica       1
# 14       2021    7          OUTROS  ...          Fibra  Pessoa Jurídica       1
# ...       ...  ...             ...  ...            ...              ...     ...
# 3210059  2021    1          OUTROS  ...             AR  Pessoa Jurídica      10
# 3210060  2021    1          OUTROS  ...             AR    Pessoa Física      19
# 3210061  2021    1          OUTROS  ...             AR    Pessoa Física      23
# 3210062  2021    1          OUTROS  ...          Fibra    Pessoa Física       1
# 3210063  2021    1          OUTROS  ...             AR    Pessoa Física      17
#
# ...

# %%
df.loc[df.Grupo_Economico == 'OUTROS', ['Grupo_Economico']] = 'GRAY TELECOM'

# %%
filter02 = df.Grupo_Economico == 'GRAY TELECOM'
df.loc[filter02]
# Out:
#           Ano  Mês Grupo_Economico  ... Meio de Acesso   Tipo de Pessoa Acessos
# 3        2021    7    GRAY TELECOM  ...          Fibra  Pessoa Jurídica       2
# 6        2021    7    GRAY TELECOM  ...          Fibra  Pessoa Jurídica       2
# 12       2021    7    GRAY TELECOM  ...          Fibra  Pessoa Jurídica       2
# 13       2021    7    GRAY TELECOM  ...          Fibra  Pessoa Jurídica       1
# 14       2021    7    GRAY TELECOM  ...          Fibra  Pessoa Jurídica       1
# ...       ...  ...             ...  ...            ...              ...     ...
# 3210059  2021    1    GRAY TELECOM  ...             AR  Pessoa Jurídica      10
# 3210060  2021    1    GRAY TELECOM  ...             AR    Pessoa Física      19
# 3210061  2021    1    GRAY TELECOM  ...             AR    Pessoa Física      23
# 3210062  2021    1    GRAY TELECOM  ...          Fibra    Pessoa Física       1
# 3210063  2021    1    GRAY TELECOM  ...             AR    Pessoa Física      17
#
# ...

# %%
pd.unique(df['Porte da Prestadora'])
# Out:
# array(['Pequeno Porte', 'Grande Porte'], dtype=object)

# %%
df.rename(columns={'Porte da Prestadora': 'Porte_da_Prestadora'}, inplace=True)

# %%
filter03 = df.'Porte da Prestadora' == 'Grande Porte'
df.loc[filter03]
#pergunta sobre erro em nome de coluna com espaço, como colocar ela nos comandos?
# Out:
#   File "<ipython-input-50-94d290d56aad>", line 1
#     filter03 = df.'Porte da Prestadora' == 'Grande Porte'
#                                       ^
# SyntaxError: invalid syntax

# %%
filter03 = df.Porte_da_Prestadora == 'Grande Porte'
df.loc[filter03]
# Out:
#           Ano  Mês Grupo_Economico  ... Meio de Acesso   Tipo de Pessoa Acessos
# 11       2021    7              OI  ...          Fibra  Pessoa Jurídica       2
# 22       2021    7              OI  ...          Fibra  Pessoa Jurídica       2
# 29       2021    7              OI  ...          Fibra  Pessoa Jurídica       4
# 30       2021    7              OI  ...          Fibra  Pessoa Jurídica       4
# 33       2021    7              OI  ...          Fibra  Pessoa Jurídica       5
# ...       ...  ...             ...  ...            ...              ...     ...
# 3210037  2021    1              OI  ...  Cabo Metálico  Pessoa Jurídica       1
# 3210038  2021    1              OI  ...  Cabo Metálico  Pessoa Jurídica       1
# 3210039  2021    1              OI  ...  Cabo Metálico  Pessoa Jurídica       1
# 3210040  2021    1              OI  ...  Cabo Metálico  Pessoa Jurídica       1
# 3210041  2021    1              OI  ...  Cabo Metálico  Pessoa Jurídica       1
#
# ...

# %%
filter04 = df.UF.isin(['CE', 'PB', 'RN'])
df.loc[filter03 & filter04]
# Out:
#           Ano  Mês   Grupo_Economico  ... Meio de Acesso   Tipo de Pessoa Acessos
# 238      2021    7  TELECOM AMERICAS  ...          Fibra  Pessoa Jurídica       4
# 261      2021    7  TELECOM AMERICAS  ...          Fibra  Pessoa Jurídica       2
# 283      2021    7  TELECOM AMERICAS  ...          Fibra  Pessoa Jurídica       6
# 289      2021    7  TELECOM AMERICAS  ...          Fibra  Pessoa Jurídica       1
# 315      2021    7  TELECOM AMERICAS  ...          Fibra  Pessoa Jurídica      17
# ...       ...  ...               ...  ...            ...              ...     ...
# 3208906  2021    1                OI  ...  Cabo Metálico    Pessoa Física       4
# 3208973  2021    1        TELEFÔNICA  ...  Cabo Metálico  Pessoa Jurídica       1
# 3209052  2021    1                OI  ...  Cabo Metálico    Pessoa Física       5
# 3209544  2021    1                OI  ...          Fibra  Pessoa Jurídica       1
# ...
